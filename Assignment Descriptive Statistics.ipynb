# %%
#Descriptive Statistics

# %%
v

# %% [markdown]
# #1. Bakery Tracks(10,12,11,15,14,13,12)
# #Ans. As we're calculating on weekly basis we'll first find average.
# Mean=10+12+11+15+14+13+12/7=87/7=12.4

# %% [markdown]
# #2. Students marks (12,15,14,16,18,20,19)
# #Ans. Mean= 12+15+14+16+18+20+19/7=114/7=16.2

# %% [markdown]
# #3. Store record shoe size (7,8,9,8,8,10,7,9)
# # Ans. Mode=8 as the size 8 is being repeated which helps to know that the concerned size is in demand

# %% [markdown]
# #4. Car dealer (8000,9500,10200,11000,50000)
# # Ans. Median = middle value in odd numbers
#        So, median = $ 10,200
#
#        Mean will not work here because of value 50,000 as an outlier

# %% [markdown]
# #5. Puzzle (25,30,27,35,40)
# # Ans. Range = Maximum time- Minimum time
#                      40-25=15
#                      So,the range is 15

# %% [markdown]
# #6.Farmer Records (100,105,98,110,120)
# # Ans. Range = Max weight-Min weight
#              =  120-98
#              =22
#              So,the range is 22 kg

# %% [markdown]
# # 7. Delivery delays
# # Ans. A=6 MINUTES
#        B= 15 MINUTES
#
#
#        A company will be more reliable as variance is less hence less chance of fluctuation whereas  B

# %% [markdown]
# #8. Cryptocurrencies Coin A SD =30,Coin B SD= 120
# # Ans. Coin B is riskier as SD is used to calculate risk & volatility
#        Coin A is at least risk as value itself

# %% [markdown]
# # 9. Electricity usage (400,420,390,450,410)
# # Ans. Mean =400+420+390+450+410/5=2070/5=414Kw
#
#        SD =

# %% [markdown]
# #10. Basketball Player (15,18,20,22,25,17,19,21)
# # Ans. Mean=15+18+20+22+25+17+19+21/8=157/8=19.6
#        Median = 15,17,18,19,20,21,22,25
#               =19+21/2
#               =20
#        Mode= no mode
#         as no value is repeated each value is occuring once
#
#         Range = Max - Min
#               =25-15
#               =10
#
#
#               SD=
